# %% [markdown]
# # CMIP6 OHC changes

# %% [markdown]
# ## Try getting OHC from google cloud storage

# %%
import pandas as pd

# for Google Cloud:
df = pd.read_csv("https://cmip6.storage.googleapis.com/pangeo-cmip6.csv")
# for AWS S3:
# df = pd.read_csv("https://cmip6-pds.s3.amazonaws.com/pangeo-cmip6.csv")

# %%
df_subset = df.query("activity_id=='CMIP' & table_id=='Amon' & variable_id=='tas'")

# %%
df_subset
# Out:
#        activity_id       institution_id          source_id experiment_id  \
# 790           CMIP         CNRM-CERFACS         CNRM-CM6-1       1pctCO2
# 16331         CMIP            NOAA-GFDL           GFDL-CM4       1pctCO2
# 17221         CMIP            NOAA-GFDL           GFDL-CM4  abrupt-4xCO2
# 17300         CMIP            NOAA-GFDL           GFDL-CM4          amip
# 17927         CMIP            NOAA-GFDL           GFDL-CM4    historical
# ...            ...                  ...                ...           ...
# 496261        CMIP                MIROC         MIROC-ES2H    historical
# 496952        CMIP                 IPSL  IPSL-CM6A-LR-INCA    historical
# 497061        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 497441        CMIP                MIROC         MIROC-ES2L    historical
# 497477        CMIP                MIROC         MIROC-ES2L    historical
#
#         member_id table_id variable_id grid_label  \
# ...

# %%
import intake

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(cat_url)

# %%
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7398 dataset(s) from 497672 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>168</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>650</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
# ...

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', variable_id='o2',
                 grid_label='gn')

# %%
cat
# Out:
# <p><strong>pangeo-cmip6 catalog with 28 dataset(s) from 180 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
# ...

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], variable_id='thetao', activity_id='CMIP', member_id='r1i1p1f1', 
                 grid_label='gn')

# %%
import numpy as np

# %% [raw]
# np.sort(col.search(experiment_id=['historical', 'ssp585'], activity_id='CMIP', member_id='r1i1p1f1',
#                  grid_label='gn').df.variable_id.unique()).tolist()

# %%
cat.df.source_id.unique()
# Out:
# array(['GFDL-CM4', 'IPSL-CM6A-LR', 'GISS-E2-1-G', 'BCC-CSM2-MR',
#        'BCC-ESM1', 'AWI-CM-1-1-MR', 'CESM2', 'MIROC6', 'SAM0-UNICON',
#        'CanESM5', 'MPI-ESM-1-2-HAM', 'NESM3', 'CAMS-CSM1-0',
#        'MPI-ESM1-2-LR', 'MPI-ESM1-2-HR', 'GFDL-ESM4', 'MCM-UA-1-0',
#        'CESM2-WACCM', 'GISS-E2-1-G-CC', 'NorESM2-LM', 'NorCPM1',
#        'FGOALS-f3-L', 'FGOALS-g3', 'ACCESS-CM2', 'NorESM2-MM',
#        'ACCESS-ESM1-5', 'CESM2-FV2', 'CESM2-WACCM-FV2', 'FIO-ESM-2-0',
#        'AWI-ESM-1-1-LR', 'CAS-ESM2-0', 'CIESM', 'CMCC-CM2-SR5',
#        'EC-Earth3-AerChem', 'TaiESM1', 'IPSL-CM5A2-INCA', 'CMCC-CM2-HR4',
#        'EC-Earth3', 'EC-Earth3-Veg-LR', 'EC-Earth3-Veg', 'EC-Earth3-CC',
#        'CMCC-ESM2', 'IPSL-CM6A-LR-INCA', 'MRI-ESM2-0'], dtype=object)

# %%
from cmip6_preprocessing.preprocessing import combined_preprocessing

# %%
help(combined_preprocessing)
# Out:
# Help on function combined_preprocessing in module cmip6_preprocessing.preprocessing:
#
# combined_preprocessing(ds)

# %%
combined_preprocessing(dset_dict['CMIP.AWI.AWI-ESM-1-1-LR.historical.Omon.gn'])
# Out:
# <xarray.Dataset>
# Dimensions:    (bnds: 2, depth: 46, member_id: 1, ncells: 126859, time: 1980, vertices: 18)
# Coordinates:
#   * depth      (depth) float64 -0.0 10.0 20.0 30.0 ... 5.4e+03 5.65e+03 5.9e+03
#     lat        (ncells) float64 dask.array<chunksize=(126859,), meta=np.ndarray>
#     lat_bnds   (ncells, vertices) float64 dask.array<chunksize=(126859, 18), meta=np.ndarray>
#     lon        (ncells) float64 dask.array<chunksize=(126859,), meta=np.ndarray>
#     lon_bnds   (ncells, vertices) float64 dask.array<chunksize=(126859, 18), meta=np.ndarray>
#   * time       (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#     time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(1980, 2), meta=np.ndarray>
#   * member_id  (member_id) <U8 'r1i1p1f1'
# Dimensions without coordinates: bnds, ncells, vertices
# Data variables:
#     thetao     (member_id, time, depth, ncells) float32 dask.array<chunksize=(1, 3, 46, 126859), meta=np.ndarray>
# Attributes:
# ...

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times':False},aggregate=True, preprocess=combined_preprocessing)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/45 00:00<00:00]
#     </div>
# ...

# %%
keys = list(dset_dict.keys())

# %% [markdown]
# # is heat content a variable in CMIP6? check ESGF!!!

# %%
keys
# Out:
# ['CMIP.AWI.AWI-ESM-1-1-LR.historical.Omon.gn',
#  'CMIP.BCC.BCC-ESM1.historical.Omon.gn',
#  'CMIP.CAS.FGOALS-g3.historical.Omon.gn',
#  'CMIP.NOAA-GFDL.GFDL-ESM4.historical.Omon.gn',
#  'CMIP.NCC.NorCPM1.historical.Omon.gn',
#  'CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.Omon.gn',
#  'CMIP.NCAR.CESM2-FV2.historical.Omon.gn',
#  'CMIP.IPSL.IPSL-CM5A2-INCA.historical.Omon.gn',
#  'CMIP.MIROC.MIROC6.historical.Omon.gn',
#  'CMIP.FIO-QLNM.FIO-ESM-2-0.historical.Omon.gn',
#  'CMIP.UA.MCM-UA-1-0.historical.Omon.gn',
#  'CMIP.MRI.MRI-ESM2-0.historical.Omon.gn',
#  'CMIP.NCAR.CESM2-WACCM-FV2.historical.Omon.gn',
#  'CMIP.MPI-M.MPI-ESM1-2-LR.historical.Omon.gn',
#  'CMIP.NUIST.NESM3.historical.Omon.gn',
#  'CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.historical.Omon.gn',
#  'CMIP.NCAR.CESM2.historical.Omon.gn',
#  'CMIP.CAS.FGOALS-f3-L.historical.Omon.gn',
#  'CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.Omon.gn',
#  'CMIP.AS-RCEC.TaiESM1.historical.Omon.gn',
# ...

# %%
keys_success = []
for key in keys:
    print(key)
    try:
        combined_preprocessing(dset_dict[key])
        keys_success.append(key)
    except Exception:
        continue
# Out:
# CMIP.AWI.AWI-ESM-1-1-LR.historical.Omon.gn
# CMIP.BCC.BCC-ESM1.historical.Omon.gn
# CMIP.CAS.FGOALS-g3.historical.Omon.gn
# CMIP.NOAA-GFDL.GFDL-ESM4.historical.Omon.gn
# CMIP.NCC.NorCPM1.historical.Omon.gn
# /srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
# ...

# %%
keys_success
# Out:
# ['CMIP.AWI.AWI-ESM-1-1-LR.historical.Omon.gn',
#  'CMIP.BCC.BCC-ESM1.historical.Omon.gn',
#  'CMIP.NOAA-GFDL.GFDL-ESM4.historical.Omon.gn',
#  'CMIP.NCC.NorCPM1.historical.Omon.gn',
#  'CMIP.NCAR.CESM2-FV2.historical.Omon.gn',
#  'CMIP.IPSL.IPSL-CM5A2-INCA.historical.Omon.gn',
#  'CMIP.MIROC.MIROC6.historical.Omon.gn',
#  'CMIP.FIO-QLNM.FIO-ESM-2-0.historical.Omon.gn',
#  'CMIP.UA.MCM-UA-1-0.historical.Omon.gn',
#  'CMIP.MRI.MRI-ESM2-0.historical.Omon.gn',
#  'CMIP.NCAR.CESM2-WACCM-FV2.historical.Omon.gn',
#  'CMIP.MPI-M.MPI-ESM1-2-LR.historical.Omon.gn',
#  'CMIP.NUIST.NESM3.historical.Omon.gn',
#  'CMIP.NCAR.CESM2.historical.Omon.gn',
#  'CMIP.CAS.FGOALS-f3-L.historical.Omon.gn',
#  'CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.Omon.gn',
#  'CMIP.CSIRO.ACCESS-ESM1-5.historical.Omon.gn',
#  'CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.Omon.gn',
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.Omon.gn',
#  'CMIP.BCC.BCC-CSM2-MR.historical.Omon.gn',
# ...

# %%
dset_dict[keys_success[2]]
