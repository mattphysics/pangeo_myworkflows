# %%
import cmip6_preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import xarray as xr
xr.set_options(display_style='html')
import intake
# %matplotlib inline

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(cat_url)
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7471 dataset(s) from 509586 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>651</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>710</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>509586</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>681</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # piControl - only GFDL-CM4

# %%
# cat = col.search(experiment_id='piControl', table_id=['3hr','Oday'], variable_id='tos')
cat = col.search(experiment_id='piControl', table_id='Oday', variable_id='tos')
#                  grid_label='gn')
cat.df
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP      NOAA-GFDL  GFDL-CM4     piControl  r1i1p1f1     Oday
#
#   variable_id grid_label                                             zstore  \
# 0         tos         gr  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/piCon...
#
#    dcpp_init_year   version
# 0             NaN  20190201

# %%
cat = col.search(experiment_id='piControl', table_id='day', variable_id='psl', source_id='GFDL-CM4')
#                  grid_label='gn')
cat.df
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP      NOAA-GFDL  GFDL-CM4     piControl  r1i1p1f1      day
# 1        CMIP      NOAA-GFDL  GFDL-CM4     piControl  r1i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0         psl        gr1  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/piCon...
# 1         psl        gr2  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/piCon...
#
#    dcpp_init_year   version
# 0             NaN  20180701
# 1             NaN  20180701

# %% [markdown]
# # historical - many models

# %%
# cat_tos = col.search(experiment_id='historical',member_id='r1i1p1f1', table_id='Oday', variable_id='tos')
cat_tos = col.search(experiment_id='historical',table_id='Oday', variable_id='tos')
#                  grid_label='gn')
cat_tos.df
# Out:
#     activity_id       institution_id          source_id experiment_id  \
# 0          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 1          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 2          CMIP                 IPSL       IPSL-CM6A-LR    historical
# 3          CMIP                 IPSL       IPSL-CM6A-LR    historical
# 4          CMIP                 IPSL       IPSL-CM6A-LR    historical
# ..          ...                  ...                ...           ...
# 334        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 335        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 336        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 337        CMIP  EC-Earth-Consortium          EC-Earth3    historical
# 338        CMIP                 IPSL  IPSL-CM6A-LR-INCA    historical
#
#      member_id table_id variable_id grid_label  \
# 0     r1i1p1f1     Oday         tos         gn
# 1     r1i1p1f1     Oday         tos         gr
# 2    r23i1p1f1     Oday         tos         gn
# 3     r1i1p1f1     Oday         tos         gn
# 4    r24i1p1f1     Oday         tos         gn
# ..         ...      ...         ...        ...
# 334  r17i1p1f1     Oday         tos         gn
# 335  r17i1p1f1     Oday         tos         gr
# 336  r18i1p1f1     Oday         tos         gr
# 337  r18i1p1f1     Oday         tos         gn
# 338   r1i1p1f1     Oday         tos         gn
#
#                                                 zstore  dcpp_init_year  \
# 0    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 1    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 2    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 3    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 4    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# ..                                                 ...             ...
# 334  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 335  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 336  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 337  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 338  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR-INCA/h...             NaN
#
#       version
# 0    20180701
# 1    20180701
# 2    20180803
# 3    20180803
# 4    20180803
# ..        ...
# 334  20210120
# 335  20210120
# 336  20210121
# 337  20210121
# 338  20210216
#
# [339 rows x 11 columns]

# %%
# cat_psl = col.search(experiment_id='historical', member_id='r1i1p1f1',table_id='day', variable_id='psl')
cat_psl = col.search(experiment_id='historical', table_id='day', variable_id='psl')
#                  grid_label='gn')
cat_psl.df
# Out:
#     activity_id       institution_id     source_id experiment_id  member_id  \
# 0          CMIP            NOAA-GFDL      GFDL-CM4    historical   r1i1p1f1
# 1          CMIP            NOAA-GFDL      GFDL-CM4    historical   r1i1p1f1
# 2          CMIP                 IPSL  IPSL-CM6A-LR    historical  r23i1p1f1
# 3          CMIP                 IPSL  IPSL-CM6A-LR    historical  r21i1p1f1
# 4          CMIP                 IPSL  IPSL-CM6A-LR    historical  r19i1p1f1
# ..          ...                  ...           ...           ...        ...
# 372        CMIP  EC-Earth-Consortium  EC-Earth3-CC    historical   r1i1p1f1
# 373        CMIP                 CMCC     CMCC-ESM2    historical   r1i1p1f1
# 374        CMIP  EC-Earth-Consortium     EC-Earth3    historical  r17i1p1f1
# 375        CMIP  EC-Earth-Consortium     EC-Earth3    historical  r18i1p1f1
# 376        CMIP            CCCR-IITM      IITM-ESM    historical   r1i1p1f1
#
#     table_id variable_id grid_label  \
# 0        day         psl        gr1
# 1        day         psl        gr2
# 2        day         psl         gr
# 3        day         psl         gr
# 4        day         psl         gr
# ..       ...         ...        ...
# 372      day         psl         gr
# 373      day         psl         gn
# 374      day         psl         gr
# 375      day         psl         gr
# 376      day         psl         gn
#
#                                                 zstore  dcpp_init_year  \
# 0    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 1    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 2    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 3    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 4    gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# ..                                                 ...             ...
# 372  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 373  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 374  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 375  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 376  gs://cmip6/CMIP6/CMIP/CCCR-IITM/IITM-ESM/histo...             NaN
#
#       version
# 0    20180701
# 1    20180701
# 2    20180803
# 3    20180803
# 4    20180803
# ..        ...
# 372  20210113
# 373  20210114
# 374  20210120
# 375  20210121
# 376  20210203
#
# [377 rows x 11 columns]

# %% [markdown]
# ### models where both daily psl and tos are available from the historical run (haven't verified that exact same model run)

# %%
np.intersect1d(cat_psl.df['source_id'].unique(),cat_tos.df['source_id'].unique())
# Out:
# array(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-ESM-1-1-LR', 'BCC-CSM2-MR',
#        'BCC-ESM1', 'CESM2', 'CESM2-FV2', 'CESM2-WACCM', 'CMCC-CM2-HR4',
#        'CMCC-CM2-SR5', 'CMCC-ESM2', 'CanESM5', 'EC-Earth3',
#        'EC-Earth3-CC', 'EC-Earth3-Veg', 'EC-Earth3-Veg-LR', 'GFDL-CM4',
#        'IPSL-CM5A2-INCA', 'IPSL-CM6A-LR', 'MIROC6', 'MPI-ESM-1-2-HAM',
#        'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NorESM2-LM',
#        'NorESM2-MM', 'SAM0-UNICON'], dtype=object)

# %%
np.intersect1d(cat_psl.df['source_id'].unique(),cat_tos.df['source_id'].unique())
# Out:
# array(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-ESM-1-1-LR', 'BCC-CSM2-MR',
#        'BCC-ESM1', 'CESM2', 'CESM2-FV2', 'CESM2-WACCM', 'CMCC-CM2-HR4',
#        'CMCC-CM2-SR5', 'CMCC-ESM2', 'CNRM-CM6-1', 'CNRM-CM6-1-HR',
#        'CNRM-ESM2-1', 'CanESM5', 'EC-Earth3', 'EC-Earth3-AerChem',
#        'EC-Earth3-CC', 'EC-Earth3-Veg', 'EC-Earth3-Veg-LR', 'GFDL-CM4',
#        'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'IPSL-CM5A2-INCA',
#        'IPSL-CM6A-LR', 'MIROC6', 'MPI-ESM-1-2-HAM', 'MPI-ESM1-2-HR',
#        'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NorESM2-LM', 'NorESM2-MM',
#        'SAM0-UNICON', 'UKESM1-0-LL'], dtype=object)

# %% [markdown]
# # MOHC

# %%
col.df['institution_id'].unique()
# Out:
# array(['CMCC', 'EC-Earth-Consortium', 'MOHC', 'ECMWF', 'NOAA-GFDL',
#        'IPSL', 'E3SM-Project', 'CNRM-CERFACS', 'NASA-GISS', 'BCC',
#        'MIROC', 'AWI', 'NCAR', 'MRI', 'CCCma', 'SNU', 'CAS', 'INM',
#        'NUIST', 'HAMMOZ-Consortium', 'CAMS', 'MPI-M', 'DWD', 'DKRZ', 'UA',
#        'NIMS-KMA', 'NCC', 'FIO-QLNM', 'KIOST', 'CSIRO-ARCCSS', 'CSIRO',
#        'CCCR-IITM', 'THU', 'AS-RCEC', 'NERC', 'ACCESS-ESM1-5', 'RUBISCO'],
#       dtype=object)

# %%
np.sort(col.df['source_id'].unique()).tolist()
# Out:
# ['ACCESS-CM2',
#  'ACCESS-ESM1-5',
#  'AWI-CM-1-1-MR',
#  'AWI-ESM-1-1-LR',
#  'BCC-CSM2-HR',
#  'BCC-CSM2-MR',
#  'BCC-ESM1',
#  'CAMS-CSM1-0',
#  'CAS-ESM2-0',
#  'CESM1-1-CAM5-CMIP5',
#  'CESM1-WACCM-SC',
#  'CESM2',
#  'CESM2-FV2',
#  'CESM2-WACCM',
#  'CESM2-WACCM-FV2',
#  'CIESM',
#  'CMCC-CM2-HR4',
#  'CMCC-CM2-SR5',
#  'CMCC-CM2-VHR4',
#  'CMCC-ESM2',
#  'CNRM-CM6-1',
#  'CNRM-CM6-1-HR',
#  'CNRM-ESM2-1',
#  'CanESM5',
#  'CanESM5-CanOE',
#  'E3SM-1-0',
#  'E3SM-1-1',
#  'E3SM-1-1-ECA',
#  'EC-Earth3',
#  'EC-Earth3-AerChem',
#  'EC-Earth3-CC',
#  'EC-Earth3-LR',
#  'EC-Earth3-Veg',
#  'EC-Earth3-Veg-LR',
#  'EC-Earth3P',
#  'EC-Earth3P-HR',
#  'EC-Earth3P-VHR',
#  'ECMWF-IFS-HR',
#  'ECMWF-IFS-LR',
#  'FGOALS-f3-H',
#  'FGOALS-f3-L',
#  'FGOALS-g3',
#  'FIO-ESM-2-0',
#  'GFDL-AM4',
#  'GFDL-CM4',
#  'GFDL-CM4C192',
#  'GFDL-ESM2M',
#  'GFDL-ESM4',
#  'GFDL-OM4p5B',
#  'GISS-E2-1-G',
#  'GISS-E2-1-G-CC',
#  'GISS-E2-1-H',
#  'GISS-E2-2-G',
#  'HadGEM3-GC31-HM',
#  'HadGEM3-GC31-LL',
#  'HadGEM3-GC31-LM',
#  'HadGEM3-GC31-MM',
#  'IITM-ESM',
#  'INM-CM4-8',
#  'INM-CM5-0',
#  'INM-CM5-H',
#  'IPSL-CM5A2-INCA',
#  'IPSL-CM6A-ATM-HR',
#  'IPSL-CM6A-LR',
#  'IPSL-CM6A-LR-INCA',
#  'KACE-1-0-G',
#  'KIOST-ESM',
#  'MCM-UA-1-0',
#  'MIROC-ES2H',
#  'MIROC-ES2L',
#  'MIROC6',
#  'MPI-ESM-1-2-HAM',
#  'MPI-ESM1-2-HR',
#  'MPI-ESM1-2-LR',
#  'MPI-ESM1-2-XR',
#  'MRI-AGCM3-2-H',
#  'MRI-AGCM3-2-S',
#  'MRI-ESM2-0',
#  'NESM3',
#  'NorCPM1',
#  'NorESM1-F',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'SAM0-UNICON',
#  'TaiESM1',
#  'UKESM1-0-LL',
#  'ssp585']

# %%
# cat = col.search(experiment_id='piControl', table_id='day', variable_id='psl', source_id='GFDL-CM4')
# cat = col.search(source_id=['HadGEM3-GC31-HM', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-LM', 'HadGEM3-GC31-MM'])
cat = col.search(institution_id='MOHC',table_id=['day','Oday','Eday','CFday'],variable_id=['psl','tos'])
#                  grid_label='gn')
cat.df
# Out:
#      activity_id institution_id        source_id experiment_id member_id  \
# 0           CMIP           MOHC  HadGEM3-GC31-LL  abrupt-4xCO2  r1i1p1f3
# 1           CMIP           MOHC  HadGEM3-GC31-LL       1pctCO2  r1i1p1f3
# 2           CMIP           MOHC  HadGEM3-GC31-LL    historical  r1i1p1f3
# 3           CMIP           MOHC  HadGEM3-GC31-LL    historical  r4i1p1f3
# 4           CMIP           MOHC  HadGEM3-GC31-LL    historical  r2i1p1f3
# ..           ...            ...              ...           ...       ...
# 170  ScenarioMIP           MOHC      UKESM1-0-LL        ssp126  r6i1p1f2
# 171  ScenarioMIP           MOHC      UKESM1-0-LL        ssp370  r6i1p1f2
# 172  ScenarioMIP           MOHC      UKESM1-0-LL        ssp126  r5i1p1f2
# 173  ScenarioMIP           MOHC      UKESM1-0-LL        ssp126  r7i1p1f2
# 174  ScenarioMIP           MOHC  HadGEM3-GC31-MM        ssp585  r4i1p1f3
#
#     table_id variable_id grid_label  \
# 0        day         psl         gn
# 1        day         psl         gn
# 2        day         psl         gn
# 3       Oday         tos         gn
# 4        day         psl         gn
# ..       ...         ...        ...
# 170      day         psl         gn
# 171      day         psl         gn
# 172      day         psl         gn
# 173      day         psl         gn
# 174      day         psl         gn
#
#                                                 zstore  dcpp_init_year  \
# 0    gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/abr...             NaN
# 1    gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/1pc...             NaN
# 2    gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/his...             NaN
# 3    gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/his...             NaN
# 4    gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/his...             NaN
# ..                                                 ...             ...
# 170  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
# 171  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
# 172  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
# 173  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
# 174  gs://cmip6/CMIP6/ScenarioMIP/MOHC/HadGEM3-GC31...             NaN
#
#       version
# 0    20190620
# 1    20190620
# 2    20190624
# 3    20190624
# 4    20190624
# ..        ...
# 170  20201009
# 171  20201014
# 172  20201015
# 173  20201015
# 174  20201026
#
# [175 rows x 11 columns]

# %%
cat.df['source_id'].unique()
# Out:
# array(['HadGEM3-GC31-LL', 'UKESM1-0-LL', 'HadGEM3-GC31-MM'], dtype=object)

# %%
# cat.search(variable_id='tos',experiment_id='historical').df
cat.search(variable_id='tos',experiment_id='historical',source_id='HadGEM3-GC31-MM').df
# Out:
#   activity_id institution_id        source_id experiment_id member_id  \
# 0        CMIP           MOHC  HadGEM3-GC31-MM    historical  r1i1p1f3
# 1        CMIP           MOHC  HadGEM3-GC31-MM    historical  r2i1p1f3
# 2        CMIP           MOHC  HadGEM3-GC31-MM    historical  r3i1p1f3
# 3        CMIP           MOHC  HadGEM3-GC31-MM    historical  r4i1p1f3
#
#   table_id variable_id grid_label  \
# 0     Oday         tos         gn
# 1     Oday         tos         gn
# 2     Oday         tos         gn
# 3     Oday         tos         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20191207
# 1  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20191218
# 2  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20200601
# 3  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20200601

# %%
# cat.search(variable_id='tos',experiment_id='historical').df
cat.search(variable_id='ts',experiment_id='historical',source_id='HadGEM3-GC31-MM').df
# Out:
# /srv/conda/envs/notebook/lib/python3.8/site-packages/intake_esm/search.py:107: UserWarning: Query returned zero results.
#   warn(message)
# Empty DataFrame
# Columns: [activity_id, institution_id, source_id, experiment_id, member_id, table_id, variable_id, grid_label, zstore, dcpp_init_year, version]
# Index: []

# %%
# cat.search(variable_id='psl',experiment_id='historical').df
cat.search(variable_id='psl',experiment_id='historical',source_id='HadGEM3-GC31-MM').df
# Out:
#   activity_id institution_id        source_id experiment_id member_id  \
# 0        CMIP           MOHC  HadGEM3-GC31-MM    historical  r1i1p1f3
# 1        CMIP           MOHC  HadGEM3-GC31-MM    historical  r2i1p1f3
# 2        CMIP           MOHC  HadGEM3-GC31-MM    historical  r3i1p1f3
# 3        CMIP           MOHC  HadGEM3-GC31-MM    historical  r4i1p1f3
#
#   table_id variable_id grid_label  \
# 0      day         psl         gn
# 1      day         psl         gn
# 2      day         psl         gn
# 3      day         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20191207
# 1  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20191218
# 2  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20200601
# 3  gs://cmip6/CMIP6/CMIP/MOHC/HadGEM3-GC31-MM/his...             NaN  20200601

# %%
# cat.search(variable_id='psl',experiment_id='historical').df
cat_hadgem3 = cat.search(variable_id=['tos','psl'],experiment_id='historical',source_id='HadGEM3-GC31-MM')

# %%
dset_dict = cat_hadgem3.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>

# %%
list(dset_dict.keys())
# Out:
# ['CMIP.MOHC.HadGEM3-GC31-MM.historical.Oday.gn',
#  'CMIP.MOHC.HadGEM3-GC31-MM.historical.day.gn']

# %%
dset_dict['CMIP.MOHC.HadGEM3-GC31-MM.historical.Oday.gn']['tos']
# Out:
# <xarray.DataArray 'tos' (member_id: 4, time: 59400, j: 1205, i: 1440)>
# dask.array<concatenate, shape=(4, 59400, 1205, 1440), dtype=float32, chunksize=(1, 19, 1205, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * i          (i) int32 0 1 2 3 4 5 6 7 ... 1433 1434 1435 1436 1437 1438 1439
#   * j          (j) int32 0 1 2 3 4 5 6 7 ... 1198 1199 1200 1201 1202 1203 1204
#     latitude   (j, i) float32 dask.array<chunksize=(1205, 1440), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(1205, 1440), meta=np.ndarray>
#   * time       (time) object 1850-01-01 12:00:00 ... 2014-12-30 12:00:00
#   * member_id  (member_id) <U8 'r1i1p1f3' 'r2i1p1f3' 'r3i1p1f3' 'r4i1p1f3'
# Attributes:
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Temperature of upper boundary of the liquid ocean, includ...
#     long_name:      Sea Surface Temperature
#     original_name:  mo: (variable_name: tos)
#     standard_name:  sea_surface_temperature
#     units:          degC

# %%
dset_dict['CMIP.MOHC.HadGEM3-GC31-MM.historical.day.gn']['psl']
# Out:
# <xarray.DataArray 'psl' (member_id: 4, time: 59400, lat: 324, lon: 432)>
# dask.array<concatenate, shape=(4, 59400, 324, 432), dtype=float32, chunksize=(1, 205, 324, 432), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -89.72 -89.17 -88.61 -88.06 ... 88.61 89.17 89.72
#   * lon        (lon) float64 0.4167 1.25 2.083 2.917 ... 357.1 357.9 358.7 359.6
#   * time       (time) object 1850-01-01 12:00:00 ... 2014-12-30 12:00:00
#   * member_id  (member_id) <U8 'r1i1p1f3' 'r2i1p1f3' 'r3i1p1f3' 'r4i1p1f3'
# Attributes:
#     cell_measures:  area: areacella
#     cell_methods:   area: time: mean
#     comment:        Sea Level Pressure
#     history:        2019-09-17T21:08:59Z altered by CMOR: replaced missing va...
#     long_name:      Sea Level Pressure
#     original_name:  mo: (stash: m01s16i222, lbproc: 128)
#     standard_name:  air_pressure_at_mean_sea_level
#     units:          Pa

# %%
sst_test = dset_dict['CMIP.MOHC.HadGEM3-GC31-MM.historical.Oday.gn']['tos'].isel(member_id=0,time=-1)
psl_test = dset_dict['CMIP.MOHC.HadGEM3-GC31-MM.historical.day.gn']['psl'].isel(member_id=0,time=-1)

test = xr.merge([sst_test,psl_test])

# %%
from dask_gateway import Gateway, GatewayCluster
gateway = Gateway()

# %%
cluster = GatewayCluster()
# cluster.adapt(minimum=2, maximum=10)  # or cluster.scale(n) to a fixed size.
cluster.adapt(minimum=2, maximum=50)  # or cluster.scale(n) to a fixed size.
client = cluster.get_client()

# %%
gateway
# Out:
# Gateway<http://10.39.245.173:8000/services/dask-gateway>

# %%
cluster
# Out:
# VBox(children=(HTML(value='<h2>GatewayCluster</h2>'), HBox(children=(HTML(value='\n<div>\n<style scoped>\n    …

# %%
client
# Out:
# <Client: 'tls://10.36.181.224:8786' processes=0 threads=0, memory=0 B>

# %%
from dask.diagnostics import ProgressBar

# %%
with ProgressBar():
    test.load()

# %%
import mat

# %%
# test['psl'].plot()
test['psl'].plot(subplot_kws={'projection':ccrs.PlateCarree()})
plt.gca().coastlines()

# %%
import cartopy.crs as ccrs

# %%
test['tos'].plot()

# %%
test['tos'].where(lambda x: (x['latitude'] > 20) & (x['latitude']< 70) & (x['longitude'] > -100) & (x['longitude'] < 20)).plot(x='longitude',y='latitude',xlim=[-100,20],ylim=[20,70])#.sel(latitude=slice(20,70))#.plot()

# %%
test['tos'].plot(subplot_kws={'projection':ccrs.PlateCarree()})#(x='longitude',y='latitude')
# test['tos'].plot(x='longitude',y='latitude',subplot_kws={'projection':ccrs.PlateCarree()})

# %%
1
# Out:
# 1
